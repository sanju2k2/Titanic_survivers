# %%
import pandas as pd
df = pd.read_csv('train_tit.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Inorder to use the column sex, let us assume that male=0 and female=1

# %%
df.replace(['male','female'],[0,1], inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
luc = df[df.Survived==1]
luc.shape
# Out:
# (342, 12)

# %%
unluc = df[df.Survived==0]
unluc.shape
# Out:
# (549, 12)

# %%
df.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass       Sex        Age     SibSp     Parch  \
# Survived
# 0          447.016393  2.531876  0.147541  30.626179  0.553734  0.329690
# 1          444.368421  1.950292  0.681287  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## from the above observation it is clear that age and cabin has more null values and those columns can be dropped as it wont affect our output

# %%
df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Sex              0.352413
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %% [markdown]
# # considered parameters
# Pclass,sex,Fare

# %%
import pandas as pd
pd.crosstab(df.Sex,df.Survived).plot(kind='bar')
# sex = 0 are male and sex = 1 are female

# %%
import pandas as pd
pd.crosstab(df.Pclass,df.Survived).plot(kind='bar')

# %% [markdown]
# According to above bar graph many people died who are in lower (3) portion and many people survived in upper (1) portion.

# %%
X = df[['Pclass','Sex','Fare']]
X
# Out:
#      Pclass  Sex      Fare
# 0         3    0    7.2500
# 1         1    1   71.2833
# 2         3    1    7.9250
# 3         1    1   53.1000
# 4         3    0    8.0500
# 5         3    0    8.4583
# 6         1    0   51.8625
# 7         3    0   21.0750
# 8         3    1   11.1333
# 9         2    1   30.0708
# 10        3    1   16.7000
# 11        1    1   26.5500
# 12        3    0    8.0500
# 13        3    0   31.2750
# 14        3    1    7.8542
# 15        2    1   16.0000
# 16        3    0   29.1250
# 17        2    0   13.0000
# 18        3    1   18.0000
# 19        3    1    7.2250
# 20        2    0   26.0000
# 21        2    0   13.0000
# 22        3    1    8.0292
# 23        1    0   35.5000
# 24        3    1   21.0750
# 25        3    1   31.3875
# 26        3    0    7.2250
# 27        1    0  263.0000
# 28        3    1    7.8792
# 29        3    0    7.8958
# ..      ...  ...       ...
# 861       2    0   11.5000
# 862       1    1   25.9292
# ...

# %%
y=df.Survived
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
reg = RandomForestClassifier(n_estimators=60)
reg.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=60, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
reg.score(X,y)
# Out:
# 0.9046015712682379

# %% [markdown]
# so we got a pretty good accuracy of about 90%

# %%
d=pd.read_csv("tests.csv")
d.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
d.replace({
    'male' : 0,
    'female' : 1
}, inplace = True)
d.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
d.drop(columns=['PassengerId','Name','Age','SibSp','Parch','Ticket','Cabin','Embarked'],inplace=True)
d.head()
d.shape
# Out:
# (418, 3)

# %%
e=d.dropna()
e.shape
# Out:
# (417, 3)

# %%
d.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Fare      1
# dtype: int64

# %%
d.fillna(method='bfill',inplace=True)

# %%
p=reg.predict(d)
d['Survived']=p
d
# Out:
#      Pclass  Sex      Fare  Survived
# 0         3    0    7.8292         0
# 1         3    1    7.0000         1
# 2         2    0    9.6875         0
# 3         3    0    8.6625         0
# 4         3    1   12.2875         1
# 5         3    0    9.2250         0
# 6         3    1    7.6292         0
# 7         2    0   29.0000         1
# 8         3    1    7.2292         1
# 9         3    0   24.1500         0
# 10        3    0    7.8958         0
# 11        1    0   26.0000         0
# 12        1    1   82.2667         1
# 13        2    0   26.0000         0
# 14        1    1   61.1750         1
# 15        2    1   27.7208         1
# 16        2    0   12.3500         0
# 17        3    0    7.2250         0
# 18        3    1    7.9250         1
# 19        3    1    7.2250         1
# 20        1    0   59.4000         0
# 21        3    0    3.1708         0
# 22        1    1   31.6833         1
# 23        1    0   61.3792         0
# ...

# %%
d.to_csv('test_tit.csv',index=True)
